# %% [markdown]
# <a href="https://colab.research.google.com/github/rajansingh387/assignments/blob/main/Exception_Handling_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# custom exceptions allow you to define your own types of errors that are not there in the exceptions list. it is a good practice to derive custom exceptions from the base exception class.
#
# by using the exception class as a base for your custom exception, you're making sure that everyone who will read your code in the future will understands what you are trying to create and how to handle it properly. it is like using same grammer technique while writing a new line. this helps in better organization, readability, and maintainability of your code.
#
# by using the Exception class as the base for your custom exception, you are ensuring that your new problem is part of the same family as all the other problems that the programming language can handle. This makes it easier for your program to understand and manage your custom exception.
# it helps in maintaing consistency, compatibility, and clarity, making it easier for your program to tackle both common and unique problems.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
"""this python program takes an exception class as an input and will print the class and its subclass,
this will start with base class and it will print main class and its sub class, also i used indent to seprate
main class and subclass and also to display hierarchy"""

# %%
def print_hierarchy(exception_class, indent=0):
    print(' ' * indent + str(exception_class))
    for subclass in exception_class.__subclasses__():
        print_hierarchy(subclass, indent + 4)

print_hierarchy(BaseException)
# Out:
# <class 'BaseException'>
#     <class 'Exception'>
#         <class 'TypeError'>
#             <class 'email.errors.MultipartConversionError'>
#             <class 'decimal.FloatOperation'>
#             <class 'numpy.core._exceptions.UFuncTypeError'>
#                 <class 'numpy.core._exceptions._UFuncBinaryResolutionError'>
#                 <class 'numpy.core._exceptions._UFuncNoLoopError'>
#                 <class 'numpy.core._exceptions._UFuncCastingError'>
#                     <class 'numpy.core._exceptions._UFuncInputCastingError'>
#                     <class 'numpy.core._exceptions._UFuncOutputCastingError'>
#             <class 'matplotlib.units.ConversionError'>
#             <class 'pyarrow.lib.ArrowTypeError'>
#             <class 'requests.exceptions.StreamConsumedError'>
#             <class 'google.auth.exceptions.InvalidType'>
#             <class 'pandas._libs.tslibs.offsets.ApplyTypeError'>
#             <class 'tqdm.std.TqdmTypeError'>
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# The arithmeticerror class is a base class for exceptions that occur during arithmetic operations in Python. it is a parent class for various arithmetic-related exception classes. Two commonly used exceptions derived from the ArithmeticError class are ZeroDivisionError and OverflowError
#
#
# ZeroDivisionError:
# this exception is raised when attempting to divide a number by zero. Division by zero is mathematically undefined, and therefore, Python raises this error to prevent such operations.
#
# OverflowError:
# this exception is raised when the result of an arithmetic operation exceeds the limits of the data type being used. For example, attempting to store a value larger than the maximum representable value for a data type will result in a overflow error.

# %%
a = 10
b = 0

try:
    result = a / b
except ZeroDivisionError as e:
    print("Error:", e)
# Out:
# Error: division by zero

# %%
import math

try:
    factorial = math.exp(10000)
except OverflowError as e:
    print("Error:", e)
# Out:
# Error: math range error

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
#
# the lookuprrror class in Python is a base clss for exceptions that occur when a lookup or indexing operation is unsuccessful due to a missing or invalid key or index. It is a parent class for lookup-related exceptions like keyerror and indexerror. this hierarchy of exception classes allows you to handle different types of lookup errors more precisely.
#
#
# keyerror- when we enter a key value that is not present in the dict it will raise key error.

# %%
#KeyError: is raised when you try to access a dictionary key that doesn't exist.
my_dict = {"a": 1, "b": 2, "c": 3}

try:
    value = my_dict["d"]
except KeyError as e:
    print("Error:", e)
# Out:
# Error: 'd'

# %% [markdown]
# **index error- index error hapens when we try to access an index in a list or data frame that dosen't exist.**

# %%
my_list = [10, 20, 30]

try:
    value = my_list[5]  # Attempting to access an index that doesn't exist
except IndexError as e:
    print("Error:", e)
# Out:
# Error: list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# ImportError and ModuleNotFoundError are both exceptions in Python that occur when there are issues related to importing and using modules in your code.
#
# **import error is a base exception that occurs when we try to import a module that dosen't exist or when imported module is not loaded properly. there are many reasons that can raise this type of error.**
# the module you are trying to export dosen't exist
#
# spelling of the module is wrong
#
# runtime errors etc.
#
# on the other hand module not found error is also a part of import error but this error raises specific type of error.
#  it is raised when a module cannot be found during the import process.in other words, it is a specialized version of ImportError that indicates that the requested module could not be located.

# %%
try:
    import module_that_does_not_exist
except ImportError as e:
    print("Module not found or cannot be imported.",e)
# Out:
# Module not found or cannot be imported. No module named 'module_that_does_not_exist'

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# catch only the exceptions that you are expecting,
# avoid using bare except statements because they can catch unexpected errors.
#
# Use specific exception classes or multiple except blocks to handle different types of exceptions separately.
#
# write only necessary code inside the try block, try to keep  it as small as possible.
#
# Pprovide clear and descriptive error Message.
#
# Use the finally block to ensure cleanup the code and to tasks like closing files, releasing resources etc.
#
# create custom exception classes when needed to raise specific error conditions in your code.
#
# inherit from the base Exception class
#
# use the Python logging module to log exceptions.
